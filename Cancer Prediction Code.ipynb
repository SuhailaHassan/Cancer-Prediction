# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from sklearn import metrics
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

# %% [markdown]
# # Load & Read Dataset

# %%
# Dataset is in a comma-seperated values (CSV) file
df = pd.read_csv('Cancer.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Dataset contains 569 record and 32 feature/attribute
df.shape
# Out:
# (569, 32)

# %%
# Get information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# Find the number of benign and malignant cases
# Benign (B): cancer at normal stage, Malignant (M): cancer at a dangerous stage
df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# # Visualization

# %%
sns.countplot(data=df, x='diagnosis', order=df['diagnosis'].value_counts().index)
# Out:
# <Axes: xlabel='diagnosis', ylabel='count'>

# %%
df['diagnosis'].value_counts().plot(kind='pie', labels = ['Benign','Malignant'], colors=['green','red'], explode = [0.2, 0], shadow = True)
plt.legend(title = "Diagnosis", loc='upper right')
plt.show()

# %% [markdown]
# # Data Preprocessing

# %%
# Find empty data cells
df.isnull().sum()

# There aren't any empty data cells
# Out:
# id                         0
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# ...

# %%
# Drop the ID column as it doesn't have useful data for training
df=df.drop(['id'], axis = 1)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## Label Encoding
# Encode categorical features into numerical ones, converting labels in diagnosis column from (B & M) into (0 & 1)

# %%
encoder = LabelEncoder()
df['diagnosis'] = encoder.fit_transform(df['diagnosis'])
df.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1        17.99         10.38          122.80     1001.0
# 1          1        20.57         17.77          132.90     1326.0
# 2          1        19.69         21.25          130.00     1203.0
# 3          1        11.42         20.38           77.58      386.1
# 4          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## Feature Scaling

# %%
X = df.loc[:, df.columns != 'diagnosis'] # Input data

# Scale Features
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
X = pd.DataFrame(X)
X.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.521037  0.022658  0.545989  0.363733  0.593753  0.792037  0.703140
# 1  0.643144  0.272574  0.615783  0.501591  0.289880  0.181768  0.203608
# 2  0.601496  0.390260  0.595743  0.449417  0.514309  0.431017  0.462512
# 3  0.210090  0.360839  0.233501  0.102906  0.811321  0.811361  0.565604
# 4  0.629893  0.156578  0.630986  0.489290  0.430351  0.347893  0.463918
#
#          7         8         9   ...        20        21        22        23  \
# 0  0.731113  0.686364  0.605518  ...  0.620776  0.141525  0.668310  0.450698
# 1  0.348757  0.379798  0.141323  ...  0.606901  0.303571  0.539818  0.435214
# 2  0.635686  0.509596  0.211247  ...  0.556386  0.360075  0.508442  0.374508
# 3  0.522863  0.776263  1.000000  ...  0.248310  0.385928  0.241347  0.094008
# 4  0.518390  0.378283  0.186816  ...  0.519744  0.123934  0.506948  0.341575
#
#          24        25        26        27        28        29
# ...

# %%
y = df[['diagnosis']] # Output labels
y.head()
# Out:
#    diagnosis
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %% [markdown]
# ## Split Dataset
# Dataset is split into training and testing dataset.

# %%
# Dataset is divided into 80% for training and 20% for testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, shuffle = True , random_state = 42)

# Shape of datasets
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((455, 30), (114, 30), (455, 1), (114, 1))

# %% [markdown]
# # Performance
# Function for evaluating the performance of machine learning models

# %%
def performance(y_test, y_pred):
    print("Model Accuracy: {:.2f}%".format(metrics.accuracy_score(y_test, y_pred)*100))
    print("Classification Report:\n", metrics.classification_report(y_test, y_pred))
    cm = metrics.confusion_matrix(y_test, y_pred)
    sns.heatmap(cm, annot = True, fmt = ".2f", xticklabels = ['Benign','Malignant'], yticklabels = ['Benign','Malignant'])
    plt.title("Confusion Matrix")
    plt.xlabel("Predicted Label", fontsize = 15)
    plt.ylabel("Actual Label", fontsize = 15)

# %% [markdown]
# # Build The Models
# Since our goal is to take in patients inputs and split them into 2 discrete classes (Benign & Malignant), we will use classification algorithms.
#
# Machine Learning Classification Algorithms:
# 1. Logistic Regression
# 2. Gaussian Naive Bayes
# 3. Support Vector Machine
# 4. Decision Tree Classifier
# 5. Random Forest Classifier
# 6. XGBClassifier

# %% [markdown]
# ## 1. Logistic Regression

# %%
logr = LogisticRegression(random_state = 0)
logr.fit(X_train, y_train.values.ravel())
logr_pred = logr.predict(X_test)

performance(y_test, logr_pred)
# Out:
# Model Accuracy: 98.25%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        71
#            1       1.00      0.95      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %% [markdown]
# ## 2. Gaussian Naive Bayes

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train.values.ravel())
gnb_pred = gnb.predict(X_test)

performance(y_test, gnb_pred)
# Out:
# Model Accuracy: 96.49%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        71
#            1       0.98      0.93      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %% [markdown]
# ## 3. Support Vector Machine

# %%
svm = SVC(kernel='linear')
svm.fit(X_train, y_train.values.ravel())
svm_pred = svm.predict(X_test)

performance(y_test, svm_pred)
# Out:
# Model Accuracy: 98.25%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      1.00      0.99        71
#            1       1.00      0.95      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.99      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %% [markdown]
# ## 4. Decision Tree Classifier

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

performance(y_test, dt_pred)
# Out:
# Model Accuracy: 93.86%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95        71
#            1       0.93      0.91      0.92        43
#
#     accuracy                           0.94       114
#    macro avg       0.94      0.93      0.93       114
# weighted avg       0.94      0.94      0.94       114

# %% [markdown]
# ## 5. Random Forest Classifier

# %%
rf = RandomForestClassifier()
rf.fit(X_train, y_train.values.ravel())
rf_pred = rf.predict(X_test)

performance(y_test, rf_pred)
# Out:
# Model Accuracy: 96.49%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.99      0.97        71
#            1       0.98      0.93      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %% [markdown]
# ## 6. XGBClassifier

# %%
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
xgb_pred = xgb.predict(X_test)

performance(y_test, xgb_pred)
# Out:
# Model Accuracy: 95.61%
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        71
#            1       0.95      0.93      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# # Models Comparison
# 1. The best models are **Logistic Regression** and **Support Vector Machine** with an accurcay of **98.25%**.
# 2. Next are **Gaussian Naive Bayes** and **Random Forest Classifier** with an accurcay of **96.49%** each.
# 3. Follwing them is **XGBClassifier**  with an accurcay of **95.61%**.
# 4. Last is **Decision Tree Classifier** with a trainig score of **93.86%** each.
